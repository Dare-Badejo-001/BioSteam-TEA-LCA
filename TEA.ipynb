# %% [markdown]
# <a href="https://colab.research.google.com/github/Dare-Badejo-001/BioSteam-TEA-LCA/blob/main/TEA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install biosteam
# Out:
# Collecting biosteam
#   Downloading biosteam-2.44.3.tar.gz (429 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 429.5/429.5 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: IPython>=7.9.0 in /usr/local/lib/python3.10/dist-packages (from biosteam) (7.34.0)
# Collecting thermosteam<0.43.0,>=0.42.0 (from biosteam)
#   Downloading thermosteam-0.42.2.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: graphviz>=0.17 in /usr/local/lib/python3.10/dist-packages (from biosteam) (0.20.3)
# Collecting chaospy>=3.3.9 (from biosteam)
#   Downloading chaospy-4.3.16-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from biosteam) (6.0.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam) (1.26.4)
# Collecting numpoly>=1.2.12 (from chaospy>=3.3.9->biosteam)
#   Downloading numpoly-1.2.13-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam) (1.13.1)
# Requirement already satisfied: setuptools>=40.9.0 in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam) (71.0.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam) (8.2.0)
# Collecting jedi>=0.16 (from IPython>=7.9.0->biosteam)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam) (4.9.0)
# Collecting pint>=0.22 (from thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading Pint-0.24.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting thermo>=0.2.25 (from thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading thermo-0.3.0-py3-none-any.whl.metadata (13 kB)
# Collecting colorpalette>=0.3.3 (from thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading colorpalette-0.3.3.tar.gz (6.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam) (2.1.4)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam) (3.7.1)
# Requirement already satisfied: xlrd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam) (2.0.1)
# Requirement already satisfied: openpyxl>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam) (3.1.5)
# Collecting free_properties>=0.3.6 (from thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading free_properties-0.3.6-py3-none-any.whl.metadata (6.1 kB)
# Collecting flexsolve>=0.5.4 (from thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading flexsolve-0.5.7.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam) (0.60.0)
# Collecting pyglet (from thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading pyglet-2.0.17-py3-none-any.whl.metadata (7.9 kB)
# Collecting ansicolors (from colorpalette>=0.3.3->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading ansicolors-1.1.8-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting colorama (from colorpalette>=0.3.3->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: llvmlite>=0.31 in /usr/local/lib/python3.10/dist-packages (from flexsolve>=0.5.4->thermosteam<0.43.0,>=0.42.0->biosteam) (0.43.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython>=7.9.0->biosteam) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (2.8.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.0.0->thermosteam<0.43.0,>=0.42.0->biosteam) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.2->thermosteam<0.43.0,>=0.42.0->biosteam) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.2->thermosteam<0.43.0,>=0.42.0->biosteam) (2024.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython>=7.9.0->biosteam) (0.7.0)
# Collecting appdirs>=1.4.4 (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam) (4.12.2)
# Collecting flexcache>=0.3 (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.3 (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading flexparser-0.3.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=7.9.0->biosteam) (0.2.13)
# Collecting fluids>=1.0.26 (from thermo>=0.2.25->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading fluids-1.0.26-py3-none-any.whl.metadata (7.2 kB)
# Collecting chemicals>=1.2.0 (from thermo>=0.2.25->thermosteam<0.43.0,>=0.42.0->biosteam)
#   Downloading chemicals-1.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->chaospy>=3.3.9->biosteam) (3.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam) (1.16.0)
# Downloading chaospy-4.3.16-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 15.4 MB/s eta 0:00:00
# Downloading free_properties-0.3.6-py3-none-any.whl (9.6 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading numpoly-1.2.13-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 10.9 MB/s eta 0:00:00
# Downloading Pint-0.24.3-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 19.3 MB/s eta 0:00:00
# Downloading thermo-0.3.0-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 84.0 MB/s eta 0:00:00
# Downloading pyglet-2.0.17-py3-none-any.whl (936 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.6/936.6 kB 42.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading chemicals-1.2.0-py3-none-any.whl (23.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.9/23.9 MB 54.6 MB/s eta 0:00:00
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.3.1-py3-none-any.whl (27 kB)
# Downloading fluids-1.0.26-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.3 MB/s eta 0:00:00
# Downloading ansicolors-1.1.8-py2.py3-none-any.whl (13 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Building wheels for collected packages: biosteam, thermosteam, colorpalette, flexsolve
#   Building wheel for biosteam (setup.py) ... done
#   Created wheel for biosteam: filename=biosteam-2.44.3-py3-none-any.whl size=475852 sha256=28e93cd732b42b4221a547fbd344aef7fbe4f99b774cbddf91e0816e9870b1e3
#   Stored in directory: /root/.cache/pip/wheels/ff/20/a9/90a42124a1754bdec855aa2674c03150693c4635d1dc6f4c9e
#   Building wheel for thermosteam (setup.py) ... done
#   Created wheel for thermosteam: filename=thermosteam-0.42.2-py3-none-any.whl size=2010543 sha256=4451f484b281435b5e4ef2bf620f098adc9f6d0f71aa3e4714a373bfea73bfaa
#   Stored in directory: /root/.cache/pip/wheels/22/ed/92/eead50d583f34c77b0ca6ad2ea88548ba4ddbb2e09e393e1a8
#   Building wheel for colorpalette (setup.py) ... done
#   Created wheel for colorpalette: filename=colorpalette-0.3.3-py3-none-any.whl size=7944 sha256=5a3fcd23504e73d03b879f22ff91a244f93e71acc7124f95a5dbffdc7f65b807
#   Stored in directory: /root/.cache/pip/wheels/70/9b/63/25d6011a2c4637816a10d70db9c46b9596d7d9f4c22a6dd376
#   Building wheel for flexsolve (setup.py) ... done
#   Created wheel for flexsolve: filename=flexsolve-0.5.7-py3-none-any.whl size=14739 sha256=16d32e4fe4db03a1f8232aacc747307b039520a39f7fc7e8752df2c3d1744e97
#   Stored in directory: /root/.cache/pip/wheels/56/43/8e/7929bf0d615e0181b9c2c05e067bc0236e5ed244ed1446fb1c
# Successfully built biosteam thermosteam colorpalette flexsolve
# Installing collected packages: free_properties, appdirs, ansicolors, pyglet, jedi, flexparser, flexcache, colorama, pint, numpoly, fluids, flexsolve, colorpalette, chemicals, chaospy, thermo, thermosteam, biosteam
# Successfully installed ansicolors-1.1.8 appdirs-1.4.4 biosteam-2.44.3 chaospy-4.3.16 chemicals-1.2.0 colorama-0.4.6 colorpalette-0.3.3 flexcache-0.3 flexparser-0.3.1 flexsolve-0.5.7 fluids-1.0.26 free_properties-0.3.6 jedi-0.19.1 numpoly-1.2.13 pint-0.24.3 pyglet-2.0.17 thermo-0.3.0 thermosteam-0.42.2

# %%
# !pip install biorefineries
# Out:
# Collecting biorefineries
#   Downloading biorefineries-2.29.0.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 27.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: biosteam<2.45.0,>=2.44.0 in /usr/local/lib/python3.10/dist-packages (from biorefineries) (2.44.3)
# Requirement already satisfied: IPython>=7.9.0 in /usr/local/lib/python3.10/dist-packages (from biosteam<2.45.0,>=2.44.0->biorefineries) (7.34.0)
# Requirement already satisfied: thermosteam<0.43.0,>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from biosteam<2.45.0,>=2.44.0->biorefineries) (0.42.2)
# Requirement already satisfied: graphviz>=0.17 in /usr/local/lib/python3.10/dist-packages (from biosteam<2.45.0,>=2.44.0->biorefineries) (0.20.3)
# Requirement already satisfied: chaospy>=3.3.9 in /usr/local/lib/python3.10/dist-packages (from biosteam<2.45.0,>=2.44.0->biorefineries) (4.3.16)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from biosteam<2.45.0,>=2.44.0->biorefineries) (6.0.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam<2.45.0,>=2.44.0->biorefineries) (1.26.4)
# Requirement already satisfied: numpoly>=1.2.12 in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam<2.45.0,>=2.44.0->biorefineries) (1.2.13)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam<2.45.0,>=2.44.0->biorefineries) (1.13.1)
# Requirement already satisfied: setuptools>=40.9.0 in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam<2.45.0,>=2.44.0->biorefineries) (71.0.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from chaospy>=3.3.9->biosteam<2.45.0,>=2.44.0->biorefineries) (8.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (4.9.0)
# Requirement already satisfied: pint>=0.22 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.24.3)
# Requirement already satisfied: thermo>=0.2.25 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.3.0)
# Requirement already satisfied: colorpalette>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.3.3)
# Requirement already satisfied: pandas>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2.1.4)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (3.7.1)
# Requirement already satisfied: xlrd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2.0.1)
# Requirement already satisfied: openpyxl>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (3.1.5)
# Requirement already satisfied: free-properties>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.3.6)
# Requirement already satisfied: flexsolve>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.5.7)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.60.0)
# Requirement already satisfied: pyglet in /usr/local/lib/python3.10/dist-packages (from thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2.0.17)
# Requirement already satisfied: ansicolors in /usr/local/lib/python3.10/dist-packages (from colorpalette>=0.3.3->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.1.8)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from colorpalette>=0.3.3->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.4.6)
# Requirement already satisfied: llvmlite>=0.31 in /usr/local/lib/python3.10/dist-packages (from flexsolve>=0.5.4->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.43.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2.8.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.0.0->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.2->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.2->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (2024.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.7.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (4.12.2)
# Requirement already satisfied: flexcache>=0.3 in /usr/local/lib/python3.10/dist-packages (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.3)
# Requirement already satisfied: flexparser>=0.3 in /usr/local/lib/python3.10/dist-packages (from pint>=0.22->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.3.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=7.9.0->biosteam<2.45.0,>=2.44.0->biorefineries) (0.2.13)
# Requirement already satisfied: fluids>=1.0.26 in /usr/local/lib/python3.10/dist-packages (from thermo>=0.2.25->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.0.26)
# Requirement already satisfied: chemicals>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from thermo>=0.2.25->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->chaospy>=3.3.9->biosteam<2.45.0,>=2.44.0->biorefineries) (3.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->thermosteam<0.43.0,>=0.42.0->biosteam<2.45.0,>=2.44.0->biorefineries) (1.16.0)
# Building wheels for collected packages: biorefineries
#   Building wheel for biorefineries (setup.py) ... done
#   Created wheel for biorefineries: filename=biorefineries-2.29.0-py3-none-any.whl size=3778583 sha256=6a7dff2f7bab02b1a24d04f3b82513d888eb3034aea82237fa4a10916aa635a1
#   Stored in directory: /root/.cache/pip/wheels/62/08/10/21ed1265fa45f714d9919158f56add186913158dd02fb771dd
# Successfully built biorefineries
# Installing collected packages: biorefineries
# Successfully installed biorefineries-2.29.0

# %%
from warnings import filterwarnings; filterwarnings('ignore')
import biosteam as bst
import numpy as np
bst.nbtutorial()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8fe907b46855> in <cell line: 2>()
#       1 from warnings import filterwarnings; filterwarnings('ignore')
# ----> 2 import biosteam as bst
#       3 import numpy as np
#       4 bst.nbtutorial()
#
# ModuleNotFoundError: No module named 'biosteam'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Inheriting from TEA objects

# %%
class SugarcaneTEA(bst.TEA):
    """
    Create a SugarcaneTEA object for techno-economic analysis of a biorefinery [1]_.

    Parameters
    ----------
    system : System
        Should contain feed and product streams.
    IRR : float
        Internal rate of return (fraction).
    duration : tuple[int, int]
        Start and end year of venture (e.g. (2018, 2038)).
    depreciation : str
        'MACRS' + number of years (e.g. 'MACRS7').
    operating_days : float
        Number of operating days per year.
    income_tax : float
        Combined federal and state income tax rate (fraction).
    lang_factor : float
        Lang factor for getting fixed capital investment from
        total purchase cost. If no lang factor, estimate capital investment
        using bare module factors.
    startup_schedule : tuple[float]
        Startup investment fractions per year
        (e.g. (0.5, 0.5) for 50% capital investment in the first year and 50%
        investment in the second).
    WC_over_FCI : float
        Working capital as a fraction of fixed capital investment.
    labor_cost : float
        Total labor cost (USD/yr).
    fringe_benefits : float
        Cost of fringe benefits as a fraction of labor cost.
    property_tax : float
        Fee as a fraction of fixed capital investment.
    property_insurance : float
        Fee as a fraction of fixed capital investment.
    supplies : float
        Yearly fee as a fraction of labor cost.
    maintenance : float
        Yearly fee as a fraction of fixed capital investment.
    administration : float
        Yearly fee as a fraction of fixed capital investment.

    References
    ----------
    .. [1] Huang, H., Long, S., & Singh, V. (2016). Techno-economic analysis of biodiesel
        and ethanol co-production from lipid-producing sugarcane. Biofuels, Bioproducts
        and Biorefining, 10(3), 299–315. https://doi.org/10.1002/bbb.1640

    """

    def __init__(self, system, IRR, duration, depreciation, income_tax,
                 operating_days, lang_factor, construction_schedule, WC_over_FCI,
                 labor_cost, fringe_benefits, property_tax,
                 property_insurance, supplies, maintenance, administration):
        # Huang et. al. does not take into account financing or startup
        # so these parameters are 0 by default
        super().__init__(system, IRR, duration, depreciation, income_tax,
                         operating_days, lang_factor, construction_schedule,
                         startup_months=0, startup_FOCfrac=0, startup_VOCfrac=0,
                         startup_salesfrac=0, finance_interest=0, finance_years=0,
                         finance_fraction=0, WC_over_FCI=WC_over_FCI)
        self.labor_cost = labor_cost
        self.fringe_benefits = fringe_benefits
        self.property_tax = property_tax
        self.property_insurance = property_insurance
        self.supplies= supplies
        self.maintenance = maintenance
        self.administration = administration

    # The abstract _DPI method should take installed equipment cost
    # and return the direct permanent investment. Huang et. al. assume
    # these values are equal
    def _DPI(self, installed_equipment_cost):
        return installed_equipment_cost

    # The abstract _TDC method should take direct permanent investment
    # and return the total depreciable capital. Huang et. al. assume
    # these values are equal
    def _TDC(self, DPI):
        return DPI

    # The abstract _FCI method should take total depreciable capital
    # and return the fixed capital investment. Again, Huang et. al.
    # assume these values are equal.
    def _FCI(self, TDC):
        return TDC

    # The abstract _FOC method should take fixed capital investment
    # and return the fixed operating cost.
    def _FOC(self, FCI):
        return (FCI*(self.property_tax + self.property_insurance
                     + self.maintenance + self.administration)
                + self.labor_cost*(1+self.fringe_benefits+self.supplies))

# %% [markdown]
# ## Cash flow analysis and results

# %%
from biorefineries import sugarcane as sc

tea = SugarcaneTEA(system=sc.sugarcane_sys,
                 IRR=0.15,
                 duration=(2018, 2038),
                 depreciation='MACRS7',
                 income_tax=0.21, # Previously 35% in published study
                 operating_days=200,
                 lang_factor=3,
                 construction_schedule=(0.4, 0.6),
                 WC_over_FCI=0.05,
                 labor_cost=2.5e6,
                 fringe_benefits=0.4,
                 property_tax=0.001,
                 property_insurance=0.005,
                 supplies=0.20,
                 maintenance=0.01,
                 administration=0.005)

tea.show() # Print TEA summary at current options
# Ignore the warnings, these are taken care of internally.
# Out:
# SugarcaneTEA: sugarcane_sys
# NPV: 1,000,073 USD at 15.0% IRR

# %%
tea.get_cashflow_table()
# Out:
#       Depreciable capital [MM$]  Fixed capital investment [MM$]  Working capital [MM$]  Depreciation [MM$]  Loan [MM$]  ...  Net earnings [MM$]  \
# 2016                       80.1                            80.1                      0                   0           0  ...                   0
# 2017                        120                             120                     10                   0           0  ...                   0
# 2018                          0                               0                      0                28.6           0  ...                9.18
# 2019                          0                               0                      0                  49           0  ...               -8.81
# 2020                          0                               0                      0                  35           0  ...                5.21
# 2021                          0                               0                      0                  25           0  ...                12.8
# 2022                          0                               0                      0                17.9           0  ...                17.7
# 2023                          0                            3.19                      0                17.9           0  ...                17.7
# 2024                          0                               0                      0                17.9           0  ...                17.7
# 2025                          0                               0                      0                8.93           0  ...                24.7
# 2026                          0                               0                      0                   0           0  ...                31.8
# 2027                          0                               0                      0                   0           0  ...                31.8
# 2028                          0                            3.19                      0                   0           0  ...                31.8
# 2029                          0                               0                      0                   0           0  ...                31.8
# 2030                          0                               0                      0                   0           0  ...                31.8
# 2031                          0                               0                      0                   0           0  ...                31.8
# 2032                          0                               0                      0                   0           0  ...                31.8
# 2033                          0                            3.19                      0                   0           0  ...                31.8
# 2034                          0                               0                      0                   0           0  ...                31.8
# 2035                          0                               0                      0                   0           0  ...                31.8
# 2036                          0                               0                      0                   0           0  ...                31.8
# 2037                          0                               0                    -10                   0           0  ...                31.8
#
#       Cash flow [MM$]  Discount factor  Net present value (NPV) [MM$]  Cumulative NPV [MM$]
# 2016            -80.1             1.15                          -92.1                 -92.1
# 2017             -130                1                           -130                  -222
# 2018             37.8             0.87                           32.9                  -189
# 2019             40.2            0.756                           30.4                  -159
# 2020             40.2            0.658                           26.5                  -133
# 2021             37.8            0.572                           21.6                  -111
# 2022             35.5            0.497                           17.7                 -93.2
# 2023             32.3            0.432                             14                 -79.3
# 2024             35.5            0.376                           13.4                 -65.9
# 2025             33.7            0.327                             11                 -54.9
# 2026             31.8            0.284                           9.03                 -45.9
# 2027             31.8            0.247                           7.86                   -38
# 2028             28.6            0.215                           6.15                 -31.9
# 2029             31.8            0.187                           5.94                 -25.9
# 2030             31.8            0.163                           5.17                 -20.8
# 2031             31.8            0.141                           4.49                 -16.3
# 2032             31.8            0.123                           3.91                 -12.4
# 2033             28.6            0.107                           3.06                 -9.31
# 2034             31.8           0.0929                           2.95                 -6.35
# 2035             31.8           0.0808                           2.57                 -3.79
# 2036             31.8           0.0703                           2.23                 -1.55
# 2037             41.8           0.0611                           2.55                     1
#
# [22 rows x 19 columns]

# %%
products = [bst.main_flowsheet('ethanol')]
costs = tea.production_costs(products)# USD/yr
np.round(costs / 1e6) # million USD / yr
# Out:
# array([58.])

# %%
feed = bst.main_flowsheet('sugarcane')
price = tea.solve_price(feed) # USD/kg
round(price, 5)
# Out:
# 0.03467

# %%
tea.IRR = tea.solve_IRR()
tea.show()
# Out:
# SugarcaneTEA: sugarcane_sys
# NPV: 4 USD at 15.1% IRR
